# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib Basic

# %%
x = np.linspace(0,5,10)
y = x**2

# %%
plt.plot(x,y)
plt.title("Hello")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %% [markdown]
# Subplot in matplot lib

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)
plt.subplot(2,2,3)
plt.plot(y,x)

# %% [markdown]
# **Objext oriented Way**

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).

# %%
fig=plt.figure(figsize = (12,8),dpi= 100)
axis1 = fig.add_axes([0.1,0.1,1,1])
axis1.plot(x,y)
axis2 =fig.add_axes([0.3,0.4,0.3,0.3])
axis2.plot(x,y)

# %% [markdown]
# **Types of plot**

# %%
plt.scatter(x,y)

# %%
from random import sample
data= sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([11.,  7., 13.,  3., 17.,  9., 12.,  8.,  8., 12.]),
#  array([ 13. , 110.4, 207.8, 305.2, 402.6, 500. , 597.4, 694.8, 792.2,
#         889.6, 987. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7edad94d7560>,
#   <matplotlib.lines.Line2D at 0x7edad94d7830>],
#  'caps': [<matplotlib.lines.Line2D at 0x7edad94d7ad0>,
#   <matplotlib.lines.Line2D at 0x7edad94d7da0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7edadb880470>],
#  'medians': [<matplotlib.lines.Line2D at 0x7edad94d7f20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7edad9300260>],
#  'means': []}

# %% [markdown]
# **saving plot**

# %%
fig = plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
