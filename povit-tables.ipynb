# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    668     21   John  January      Q1
# 1  2023-01-02       B   West    260     92   Mary  January      Q1
# 2  2023-01-03       C  North    763     45    Bob  January      Q1
# 3  2023-01-04       D  South    861     63  Alice  January      Q1
# 4  2023-01-05       A   East    788     17   John  January      Q1
# 5  2023-01-06       B   West    744     60   Mary  January      Q1
# 6  2023-01-07       C  North    351     25    Bob  January      Q1
# 7  2023-01-08       D  South    275     15  Alice  January      Q1
# 8  2023-01-09       A   East    439     73   John  January      Q1
# 9  2023-01-10       B   West    144     72   Mary  January      Q1
# 10 2023-01-11       C  North    776     89    Bob  January      Q1
# 11 2023-01-12       D  South    485     28  Alice  January      Q1
# 12 2023-01-13       A   East    732     48   John  January      Q1
# 13 2023-01-14       B   West    113     32   Mary  January      Q1
# 14 2023-01-15       C  North    958     50    Bob  January      Q1
# 15 2023-01-16       D  South    667     38  Alice  January      Q1
# 16 2023-01-17       A   East    448     63   John  January      Q1
# 17 2023-01-18       B   West    821     30   Mary  January      Q1
# 18 2023-01-19       C  North    202     87    Bob  January      Q1
# 19 2023-01-20       D  South    718     34  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales",index = "Region",columns ="Product",aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East     668.0    NaN    NaN    NaN
# North      NaN    NaN  763.0    NaN
# South      NaN    NaN    NaN  667.0
# West       NaN  260.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df,values=["Sales","Units"],index="Region",columns="Product")
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     615.0    NaN    NaN    NaN  44.4   NaN   NaN   NaN
# North      NaN    NaN  610.0    NaN   NaN   NaN  59.2   NaN
# South      NaN    NaN    NaN  601.2   NaN   NaN   NaN  35.6
# West       NaN  416.4    NaN    NaN   NaN  57.2   NaN   NaN

# %% [markdown]
# **Cross Tab**

# %%
pd.crosstab(df["Region"],df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
